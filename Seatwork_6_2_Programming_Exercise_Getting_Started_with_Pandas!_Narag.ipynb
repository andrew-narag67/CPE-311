# %% [markdown]
# Using the 2019_Yellow_Taxi_Trip_Data.csvLinks to an external site. dataset, accomplish the following items and submit a PDF of the notebook:

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create a DataFrame by reading in the 2019_Yellow_Taxi_Trip_Data.csv file. Examine the first 5 rows.

# %%
data = pd.read_csv("/content/drive/MyDrive/Foldah/2019_Yellow_Taxi_Trip_Data.csv")
data.head(5)
# Out:
#    vendorid     tpep_pickup_datetime    tpep_dropoff_datetime  \
# 0         2  2019-10-23T16:39:42.000  2019-10-23T17:14:10.000
# 1         1  2019-10-23T16:32:08.000  2019-10-23T16:45:26.000
# 2         2  2019-10-23T16:08:44.000  2019-10-23T16:21:11.000
# 3         2  2019-10-23T16:22:44.000  2019-10-23T16:43:26.000
# 4         2  2019-10-23T16:45:11.000  2019-10-23T16:58:49.000
#
#    passenger_count  trip_distance  ratecodeid store_and_fwd_flag  \
# 0                1           7.93           1                  N
# 1                1           2.00           1                  N
# 2                1           1.36           1                  N
# 3                1           1.00           1                  N
# 4                1           1.96           1                  N
#
#    pulocationid  dolocationid  payment_type  fare_amount  extra  mta_tax  \
# 0           138           170             1         29.5    1.0      0.5
# ...

# %% [markdown]
# Find the dimensions (number of rows and number of columns) in the data.

# %%
print(data.info())
print("Size of Data (Rows Multiplied by Columns):")
print(data.size)
print("Shape of Data:")
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   vendorid               10000 non-null  int64
#  1   tpep_pickup_datetime   10000 non-null  object
#  2   tpep_dropoff_datetime  10000 non-null  object
#  3   passenger_count        10000 non-null  int64
#  4   trip_distance          10000 non-null  float64
#  5   ratecodeid             10000 non-null  int64
#  6   store_and_fwd_flag     10000 non-null  object
#  7   pulocationid           10000 non-null  int64
#  8   dolocationid           10000 non-null  int64
#  9   payment_type           10000 non-null  int64
#  10  fare_amount            10000 non-null  float64
#  11  extra                  10000 non-null  float64
#  12  mta_tax                10000 non-null  float64
#  13  tip_amount             10000 non-null  float64
# ...

# %% [markdown]
# Using the data in the 2019_Yellow_Taxi_Trip_Data.csv file, calculate summary statistics for the fare_amount, tip_amount, tolls_amount, and total_amount columns

# %%
data.describe().T
# Out:
#                          count        mean        std    min      25%    50%  \
# vendorid               10000.0    1.633700   0.481817   1.00    1.000    2.0
# passenger_count        10000.0    1.497700   1.139353   0.00    1.000    1.0
# trip_distance          10000.0    3.015250   4.148063   0.00    0.920    1.5
# ratecodeid             10000.0    1.084200   0.418244   1.00    1.000    1.0
# pulocationid           10000.0  166.900400  63.791288   1.00  132.000  162.0
# dolocationid           10000.0  166.313500  68.525953   1.00  132.000  163.0
# payment_type           10000.0    1.301000   0.486644   1.00    1.000    1.0
# fare_amount            10000.0   15.106313  13.954762 -52.00    7.000   10.0
# extra                  10000.0    1.960235   1.392940  -4.50    1.000    1.0
# mta_tax                10000.0    0.492450   0.071544  -0.50    0.500    0.5
# tip_amount             10000.0    2.634494   3.409800   0.00    0.000    2.0
# ...

# %% [markdown]
# Isolate the fare_amount, tip_amount, tolls_amount, and total_amount for the longest trip by distance (trip_distance).

# %%
isolate = data[data['trip_distance'] == data['trip_distance'].max()][["trip_distance","fare_amount", "tip_amount", "tolls_amount", "total_amount"]]
print(isolate)
# Out:
#       trip_distance  fare_amount  tip_amount  tolls_amount  total_amount
# 8338          38.11        176.0       18.29          6.12        201.21
