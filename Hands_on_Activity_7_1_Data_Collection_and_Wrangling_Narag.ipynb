# %% [markdown]
# Module 7: Data Wrangling with Pandas
#
# CPE311 Computational Thinking with Python
#
# Submitted by: Narag, Andrew Jermaine C.
# Performed on: 02/24/2026
# Submitted on: 02/24/2026
#
# Submitted to: Engr. Neil Barton Matira

# %% [markdown]
# ## 7.1 Supplementary Activity
#
# Using the datasets provided, perform the following exercises:

# %%
import numpy as np
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Exercise 1

# %% [markdown]
# We want to look at data for the Facebook, Apple, Amazon, Netflix, and Google (FAANG) stocks, but we were given each as a separate CSV file. Combine them into a single file and store the dataframe of the FAANG data as faang for the rest of the exercises:
#
# 1. Read each file in.
#
# 2. Add a column to each dataframe, called ticker, indicating the ticker symbol it is for (Apple's is AAPL, for example). This is how you look up a stock. Each file's name is also the ticker symbol, so be sure to capitalize it.
#
# 3. Append them together into a single dataframe.
#
# 4. Save the result in a CSV file called faang.csv.

# %%
import pandas as pd
FB = pd.read_csv('/content/drive/MyDrive/Foldah/fb.csv')
AAPL = pd.read_csv('/content/drive/MyDrive/Foldah/aapl.csv')
AMZN = pd.read_csv('/content/drive/MyDrive/Foldah/amzn.csv')
NFLX = pd.read_csv('/content/drive/MyDrive/Foldah/nflx.csv')
GOOG = pd.read_csv('/content/drive/MyDrive/Foldah/goog.csv')

FB['ticker'] = 'FB'
AAPL['ticker'] = 'AAPL'
AMZN['ticker'] = 'AMZN'
NFLX['ticker'] = 'NFLX'
GOOG['ticker'] = 'GOOG'

faang = pd.concat([FB, AAPL, AMZN, NFLX, GOOG], ignore_index=True)
faang.to_csv('faang.csv', index=False)

faang.head(4)
# Out:
#          date    open    high       low   close    volume ticker
# 0  2018-01-02  177.68  181.58  177.5500  181.42  18151903     FB
# 1  2018-01-03  181.88  184.78  181.3300  184.67  16886563     FB
# 2  2018-01-04  184.90  186.21  184.0996  184.33  13880896     FB
# 3  2018-01-05  185.59  186.90  184.9300  186.85  13574535     FB

# %% [markdown]
# # Exercise 2

# %% [markdown]
# With faang, use type conversion to change the date column into a
#
# datetime and the volume column into integers. Then, sort by date and ticker.
#
# Find the seven rows with the highest value for volume.
#
# Right now, the data is somewhere between long and wide format. Use melt() to make it completely long format. Hint: date and ticker are our ID variables (they uniquely identify each row). We need to melt the rest so that we don't have separate columns for open, high, low, close, and volume.

# %%
faang['date'] = pd.to_datetime(faang['date'])
faang['volume'] = pd.to_numeric(faang['volume'])
seven_rows = faang.nlargest(7, 'volume')

print(seven_rows)
# Out:
#           date      open      high       low     close     volume ticker
# 142 2018-07-26  174.8900  180.1300  173.7500  176.2600  169803668     FB
# 53  2018-03-20  167.4700  170.2000  161.9500  168.1500  129851768     FB
# 57  2018-03-26  160.8200  161.1000  149.0200  160.0600  126116634     FB
# 54  2018-03-21  164.8000  173.4000  163.3000  169.3900  106598834     FB
# 433 2018-09-21  219.0727  219.6482  215.6097  215.9768   96246748   AAPL
# 496 2018-12-21  156.1901  157.4845  148.9909  150.0862   95744384   AAPL
# 463 2018-11-02  207.9295  211.9978  203.8414  205.8755   91328654   AAPL

# %%
long_faang = faang.melt(id_vars=['date','ticker'], value_vars = ['open', 'high', 'low', 'close', 'volume'])
print(long_faang)
# Out:
#            date ticker variable       value
# 0    2018-01-02     FB     open      177.68
# 1    2018-01-03     FB     open      181.88
# 2    2018-01-04     FB     open      184.90
# 3    2018-01-05     FB     open      185.59
# 4    2018-01-08     FB     open      187.20
# ...         ...    ...      ...         ...
# 6270 2018-12-24   GOOG   volume  1590328.00
# 6271 2018-12-26   GOOG   volume  2373270.00
# 6272 2018-12-27   GOOG   volume  2109777.00
# 6273 2018-12-28   GOOG   volume  1413772.00
# 6274 2018-12-31   GOOG   volume  1493722.00
#
# [6275 rows x 4 columns]

# %% [markdown]
# # Exercise 3

# %% [markdown]
# Using web scraping, search for the list of the hospitals, their address and contact information. Save the list in a new csv file, hospitals.csv.
#
# Using the generated hospitals.csv, convert the csv file into pandas dataframe. Prepare the data using the necessary preprocessing techniques.

# %%
! pip install Bs4 requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Bs4 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (0.0.2)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.32.2)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from Bs4) (4.12.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tipqc\appdata\roaming\python\python312\site-packages (from requests) (2026.1.4)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->Bs4) (2.5)

# %%
import requests
from bs4 import BeautifulSoup

def getData(url):
    r = requests.get(url)
    print(r.status_code)
    return r.text

url = "https://www.google.com"
html = getData(url)
# Out:
# 200

# %%
from selenium import webdriver
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.firefox.options import Options
from webdriver_manager.firefox import GeckoDriverManager
import time

options = Options()
options.binary_location = r"C:\Program Files\Mozilla Firefox\firefox.exe"

service = Service(GeckoDriverManager().install())

driver = webdriver.Firefox(service=service, options=options)

driver.get("https://icare.com.ph/icare-accredited-health-partners/")
time.sleep(5)

print("Page Title:", driver.title)
# Out:
# Page Title: iCare Accredited Health Partners - iCare Top Affordable HMO Philippines

# %%
soup = BeautifulSoup(driver.page_source, "html.parser")

table = soup.find("table")

headers = [th.text.strip() for th in table.find_all("th")]


print("Headers:", headers)
# Out:
# Headers: ['Provider Name', 'Type of Facility', 'City', 'Province', 'Region', 'Address', 'Contact Number', 'Email Address']

# %%
provider_index = headers.index("Provider Name")
address_index = headers.index("Address")
contact_index = headers.index("Contact Number")

# %%
rows = table.find("tbody").find_all("tr")

data = []

for row in rows:
    cols = row.find_all("td")

    provider = cols[provider_index].text.strip()
    address = cols[address_index].text.strip()
    contact = cols[contact_index].text.strip()

    data.append({
        "Provider Name": provider,
        "Address": address,
        "Contact Number": contact
    })

for item in data[:100]:
    print(item)
# Out:
# {'Provider Name': 'TAGUM EYE SURGICENTER', 'Address': 'GCA BUILDING, NATIONAL HIGHWAY, VISAYAN VILLAGE', 'Contact Number': '(084) 655 6751'}
# {'Provider Name': 'CORE PHYSIOTHERAPY SERVICES OPC', 'Address': '2ND FLOOR HOOGAH BUILDING J.P LAUREL HIGHWAY, BARANGAY MARAWOY', 'Contact Number': ''}
# {'Provider Name': 'DIPOLOG DOCTORS MEDICAL AND DIAGNOSTIC CLINIC', 'Address': 'PUROK MORNINGSTAR BRGY. OLINGAN', 'Contact Number': ''}
# {'Provider Name': 'FIX AND HEALTH ME', 'Address': 'EASTBLOCK BLDG A DOOR 12A, CIRCUMFERENTIAL RD BRGY VILLAMONTE', 'Contact Number': ''}
# {'Provider Name': 'OPTIMUM HEALTHCARE (SOLID SOUTH MEDI 6 INC.)', 'Address': 'BLOCK 3 LOT 3 E. RODRIGUEZ AVE. GREGORIA HEIGHTS SUBD., SAN ISIDRO,', 'Contact Number': '(02) 8398 3067'}
# {'Provider Name': 'TOP LAB MD CORPORATION - TARLAC', 'Address': 'LIP BLDG., LOT 2A, LUISITA ACCESS ROAD,  2301', 'Contact Number': '0456-063121'}
# {'Provider Name': '1HEALTHCARE CLINIC AND DIAGNOSTICS CENTER, INC.', 'Address': '2F MBP PLAZA ALONG MCARTHUR HWAY BRGY. CAMACHILES MABALACAT', 'Contact Number': '0906-952-8551/0943-441-959'}
# {'Provider Name': '1LIFE INC. CLINIC', 'Address': '71 SIMOUN BRGY STO. DOMINGO', 'Contact Number': '86356507'}
# {'Provider Name': '3 STAR MEDICAL CLINIC AND DIAGNOSTIC CENTER, INC.', 'Address': 'U 103-104 & MC-4,VICTORIA STATION I,BRGY. SOUTH TRIANGLE, GMA EDSA KAMUNING', 'Contact Number': '0908 279 4202'}
# {'Provider Name': 'A MAINSTREET PT CLINIC', 'Address': 'MCARTHUR HIGHWAY, CALINAN, DAVAO', 'Contact Number': '(082) 2950710'}
# {'Provider Name': 'A PLUS HEALTHCARE MEDICAL & DIAGNOSTIC CORPORATION', 'Address': '2/F 316 BLDG. EDSA MONUMENTO , BRGY 86 ZONE 8\t KALOOCAN CITY, MANILA', 'Contact Number': ''}
# {'Provider Name': 'A-A ANIMAL BITE CENTER', 'Address': '2ND FLR UNIT F. B25 L.C. DONA SOLEDAD AVE. BETTER LIVING SUBD., DON BOSCO', 'Contact Number': ''}
# {'Provider Name': 'A-D ANIMAL BITE CENTER', 'Address': '0412-B QUIRINO AVENUE LA HUERTA', 'Contact Number': ''}
# {'Provider Name': 'A-D ANIMAL BITE CENTER-LAS PINAS', 'Address': '28 DIEGO CERA AVE, LAS PIÑAS, 1742  METRO MANILA', 'Contact Number': ''}
# {'Provider Name': 'A-D ANIMAL BITE CENTER-TAYTAY RIZAL', 'Address': '24TH NATIONAL ROAD, BRGY MUZON,  TAYTAY, 1920 RIZAL', 'Contact Number': ''}
# {'Provider Name': 'A-D ANIMAL BITE CLINIC-DASMARINAS CAVITE', 'Address': 'STALL NO. 2, 2ND FLOOR, BAUCAM  BUILDING, 3 PALIPARAN RD, DASMARIÑAS,', 'Contact Number': ''}
# {'Provider Name': 'A-D ANTI RABIES  VACCINE CLINIC-BACOOR', 'Address': 'SOUTH SUSANA HOMES, JOZA BUILDING  UNIT D. BLK. 1 LOT 13, MOLINO 2,  BACOOR,', 'Contact Number': ''}
# {'Provider Name': 'A-O LINK MEDICAL AND DIAGNOSTIC CENTER', 'Address': 'ROMANVILLE  COMM. BLDG., SAN FERNANDO', 'Contact Number': '(043) 403 6786'}
# {'Provider Name': 'A. ZARATE GENERAL HOSPITAL', 'Address': 'ATLAS CPD., NAGA RD., LAS PIÑAS CITY', 'Contact Number': '02-8 8746903'}
# {'Provider Name': 'A.B.G. SPECIALIST & DIAGNOSTIC CENTER-IBA', 'Address': 'G 558 NATIONAL ROAD, PALANGINAN', 'Contact Number': ''}
# {'Provider Name': 'A.B.G. SPECIALIST & DIAGNOSTIC CENTER-MASINLOC', 'Address': 'A.B.G. SPECIALIST & DIAGNOSTIC CENTER-MASINLOC', 'Contact Number': ''}
# {'Provider Name': 'A2GV MEDICAL AND DIAGNOSTIC CENTER', 'Address': 'NO.2 YEN ST. COR DOLLAR ST. MICHAEL HOMES BRGY. PANDAYAN,', 'Contact Number': '044-3239054'}
# {'Provider Name': 'ABESAMIS VISION CARE CENTER-MAKATI', 'Address': 'RM. 905 MEDICAL PLAZA BLDG. COR. AMORSOLO, MAKATI', 'Contact Number': '(02)8133482'}
# {'Provider Name': 'AC LABORATORY AND MEDICAL CLINIC', 'Address': '0068 M. PARRAS ST., POBLACION 2 TAGBILARAN CITY BOHOL', 'Contact Number': '(038) 412-7707'}
# {'Provider Name': 'ACC PHYSICAL THERAPY CLINIC - BACOOR', 'Address': 'GROUND FLOOR, GPI BUILDING, TIRONA HWY, BACOOR, 4102 CAVITE', 'Contact Number': ''}
# {'Provider Name': 'ACC PHYSICAL THERAPY CLINIC - IMUS', 'Address': 'ALIVIA COMMERCIAL COMPLEX, 1-E ANABU RD, IMUS, 4103 CAVITE', 'Contact Number': ''}
# {'Provider Name': 'ACC PHYSICAL THERAPY CLINIC-CARIDAD', 'Address': 'MEDICAL ARTS CPD. BAUTISTA HOSPITAL P. BURGOS AVE., CARIDAD, CAVITE', 'Contact Number': '(046)4848604'}
# {'Provider Name': 'ACC PHYSICAL THERAPY CLINIC-NOVELETA', 'Address': 'UNIT B ROMA BLDG, MAGDIWANG HI-WAY, NOVELETA, CAVITE', 'Contact Number': '046438 8303'}
# {'Provider Name': 'ACCESS LABORATORY INC', 'Address': '3 ASUNCION, MORNING BREEZE SUBDIVISION,', 'Contact Number': '02-84425971'}
# {'Provider Name': 'ACCU-RIGHT MEDICAL AND DIAGNOSTIC CENTER', 'Address': '2ND FLOOR ELORCHA REALTY BLDG. PIO PEDROSA AVE BRGY.LUNTAD PALO LEYTE', 'Contact Number': ''}
# {'Provider Name': 'ACCUCELL DIAGNOSTIC CENTER', 'Address': 'FEMAR BLDG. QUEZPON ST. SAN ROQUE', 'Contact Number': '(02) 8571 9110'}
# {'Provider Name': 'ACCUHEAR HEARING CENTER', 'Address': 'DOOR 3, DNORTHWAY BUILDING LOT 1 & 2, BLOCK 45 BS AQUINO DRIVE', 'Contact Number': '(034) 447 7048'}
# {'Provider Name': 'ACCULAB DRUG TESTING AND MEDICAL SERVICES', 'Address': 'GEN. LUNA ST', 'Contact Number': ''}
# {'Provider Name': 'ACCULAB MEDICAL CLINIC AND LABORATORY', 'Address': '3RD FLOOR, MCF LIFESTULE HUB. TIKAY', 'Contact Number': ''}
# {'Provider Name': 'ACCUMED ANGELES CITY', 'Address': 'MAIN:2442 ENTIERRO ST.,STO. CRISTO,ANGELES CITY', 'Contact Number': '(045) 626-1823 / 0917-805-8805/322-0947/887-1198'}
# {'Provider Name': 'ACCUMED MABALACAT', 'Address': 'LOT 15 BLK. 10 MCARTHUR HI-WAY, MABIGA,', 'Contact Number': '(045) 331-8706 / (045) 458-0319'}
# {'Provider Name': 'ACCUPROF LABORATORY AND DIAGNOSTIC CENTER', 'Address': 'QUIMSON ST. COR MABINI ST. BRGY. QUEZON DISTRICT', 'Contact Number': ''}
# {'Provider Name': 'ACCURA IMAGING & MEDICAL LABORATORY', 'Address': 'UNIT 107 G/F, TANGO PLAZA BUILDING QUEENS ROAD CAMPUTHAW', 'Contact Number': '032 345 0582'}
# {'Provider Name': 'ACCUTRUST DIAGNOSTIC LABORATORY', 'Address': 'UNIT 206, BLDG. 1, GREAT MALL OF CENTRAL LUZON, XEVERA SUBD., BRGY. TABUN', 'Contact Number': '09229913310'}
# {'Provider Name': 'ACE DIAGNOSTICS - FAIRVIEW', 'Address': 'UNIT 2-5 CPE BLDG., DON MARIANO MARCOS AVE., BRGY. FAIRVIEW', 'Contact Number': '84613901 / 84613906'}
# {'Provider Name': 'ACE DIAGNOSTICS - NOVALICHES', 'Address': '789 QUIRINO HIGHWAY, GULOD NOVALICHES', 'Contact Number': '89831966 / 89831968'}
# {'Provider Name': 'ACE DIAGNOSTICS - VALENZUELA', 'Address': 'UNIT 116-119 ARBORTOWNE PLAZA 2, KARUHATAN ROAD, GEN.T DE LEON', 'Contact Number': '86355918 /86366291'}
# {'Provider Name': 'ACE MEDICAL CENTER SARIAYA', 'Address': 'NATIONAL HI-WAY BRGY. GIBANGA', 'Contact Number': '042 784 1252'}
# {'Provider Name': 'ACEBEDO GENERAL HOSPITAL', 'Address': '849 GEN. LUIS ST. BAGBAGUIN', 'Contact Number': '09465735811/(02)88064298'}
# {'Provider Name': 'ACES/PSH EYE REFERRAL CLINICS', 'Address': 'PERPETUAL SUCCOUR HOSPITAL 6F SPC SPECIALTY BLDG., GORORDO AVE.,', 'Contact Number': '(032)2341520/2321727'}
# {'Provider Name': 'ACTIVELIFE CHICAGO PHYSICAL THERAPY SERVICES-MANDALUYONG', 'Address': '1001 10F CITYLAND SHAW TOWER COR ST. FRANCIS BRGY. WACK WACK', 'Contact Number': '(02) 7621 7418 or'}
# {'Provider Name': 'ADONIS MEDICAL CLINIC AND LABORATORY', 'Address': '262 A. MABINI ST. PINAGBAKAHAN', 'Contact Number': ''}
# {'Provider Name': 'ADRAMEDIX MEDICAL AND DIAGNOSTIC CENTER', 'Address': 'F.T. CATAPUSAN RD', 'Contact Number': '(02) 8654 9545'}
# {'Provider Name': 'ADVANCE HEALTH SERVICES COOPERATIVE-CEBU', 'Address': 'PCF BUILDING, #20 M. ZOSA STREET, CAPITOL SITE', 'Contact Number': '032-238-4693 / 09175059558'}
# {'Provider Name': 'ADVANCED BONE LOGISTIC VENTURES, INC.', 'Address': 'LEV 4 ROBINSONS CYBERGATE, J. LLORENTE ST. CEBU', 'Contact Number': '032-239-2211'}
# {'Provider Name': 'ADVANCED LAB SOLUTION BY HI-PRECISION DIAGNOSTICS-CENTURIA', 'Address': '9F CENTURIA MEDICAL MAKATI, KALAYAAN AVE., COR. SALAMANCA ST. BRGY. POBLACION ,', 'Contact Number': '(02)7938606'}
# {'Provider Name': 'ADVENT HEALTH MEDICAL AND DIAGNOSTIC CLINIC-BINAN', 'Address': '747 PEDRO ESCUETA ST. SAN ANTONIO', 'Contact Number': '(049)5114343'}
# {'Provider Name': 'ADVENT HEALTH MEDICAL AND DIAGNOSTIC CLINIC-CABUYAO', 'Address': '2ND FLR. DON ONOFRE BLDG. NAT’L. HI-WAY, BRGY SALA', 'Contact Number': '(049) 304 – 3150'}
# {'Provider Name': 'ADVENTIST HOSPITAL PALAWAN CLINIC', 'Address': 'BRGY. CORONG-CORONG,', 'Contact Number': '048-5508006/'}
# {'Provider Name': 'ADVENTIST HOSPITAL-CALBAYOG, INC.', 'Address': 'KM 730 DAANG MAHARLIKA SAN POLICARPIO', 'Contact Number': '(055) 209 1323'}
# {'Provider Name': 'ADVENTIST HOSPITAL-CEBU, INC.', 'Address': '400 TRES DE ABRIL ST., SAN NICOLAS, MILLER COMPD. CEBU CITY', 'Contact Number': '(032)2612100/2611974'}
# {'Provider Name': 'ADVENTIST HOSPITAL-DAVAO, INC.', 'Address': 'KM.7 MCARTHUR HI-WAY, BANGKAL', 'Contact Number': '(082)2972597/ 2972761/297-6859'}
# {'Provider Name': 'ADVENTIST HOSPITAL-PALAWAN, INC.', 'Address': 'JUNCTION 2 BRGY SAN PEDRO, PUERTO PRINCESA CITY PALAWAN', 'Contact Number': '048-433-1247'}
# {'Provider Name': 'ADVENTIST HOSPITAL-SANTIAGO CITY, INC', 'Address': 'MABINI', 'Contact Number': '(078) 324 7259'}
# {'Provider Name': 'ADVENTIST MEDICAL CENTER AND COLLEGE MANILA, INC.', 'Address': '1975 DONADA ST. PASAY', 'Contact Number': '02-8525-9191'}
# {'Provider Name': 'ADVENTIST MEDICAL CENTER-BACOLOD, INC.', 'Address': 'CV RAMOS AVE., TACULING BACOLOD CITY', 'Contact Number': '(034)4334831 TO 36/4887777'}
# {'Provider Name': 'ADVENTIST MEDICAL CENTER-ILIGAN', 'Address': 'ILIGAN CITY, LANAO DEL NORTE', 'Contact Number': ''}
# {'Provider Name': 'ADVENTIST MEDICAL CENTER-VALENCIA CITY, INC.', 'Address': 'A. AGUILAR ST. POBLACION', 'Contact Number': '(088) 828-2037'}
# {'Provider Name': 'AGAPE MULTISPECIALTY REHABILITATION CENTER', 'Address': 'LOT 1, BLOCK 96, PARADISE VILLE, BARANGAY TUNGKONG MANGGA', 'Contact Number': ''}
# {'Provider Name': 'AGILE PHYSIO RECOVERY PHYSICAL THERAPY-CUBAO', 'Address': 'UNIT 3C ST. MARTIN BUILDING, 17 WEST POINT STREET, CUBAO', 'Contact Number': '0965 996 3354'}
# {'Provider Name': 'AGILE PHYSIO RECOVERY PHYSICAL THERAPY-TAFT', 'Address': 'RM 408 DONA FELISA SYJUCO BLDG. TAFT AVE. COR REMEDIOS ST. MALATE', 'Contact Number': ''}
# {'Provider Name': 'AGILE PHYSIORECOVERY PHYSICAL THERAPY CLINIC  - ANGONO', 'Address': 'UNIT NO. 15 & 16 LEXAR ANGONO BUILDING, M.L. QUEZON AVENUE CORNER EDENVILLE SUB', 'Contact Number': ''}
# {'Provider Name': 'AGUANTA MEDICAL AND DIAGNOSTIC CENTER CORP.', 'Address': 'CHRISTIANY BLDG. D.C SANCHEZ ST. 787 STA. CRUZ SANTO NINO', 'Contact Number': '(032) 266 8042'}
# {'Provider Name': 'AIC DIAGNOSTIC INC.', 'Address': '2/F CGN BLDG. NATIONAL HIGHWAY COR. VILLEGAS ST. SAN PEDRO', 'Contact Number': ''}
# {'Provider Name': 'AISAH MEDICAL HOSPITAL', 'Address': 'SAN PEDRO DISTRICT', 'Contact Number': '062-92015-1582'}
# {'Provider Name': 'AKBAY STROKE CARE AND NEUROLOGICAL REHAB CENTER INC.', 'Address': 'CDO POLYMEDIC MEDICAL PLAZA KAUSWAGAN HI-WAY', 'Contact Number': ''}
# {'Provider Name': 'ALAB NG PUSO CARDIOVACULAR DIAGNOSTICS', 'Address': 'GROUND FLOOR OF PADILLA BUILDING (KINGSWAY INN), PUROK 13, BRGY SARAY-TIBANGA, A', 'Contact Number': '063-3025033'}
# {'Provider Name': 'ALABANG MEDICAL CENTER', 'Address': 'ALABANG-ZAPOTE RD.,', 'Contact Number': '(02)8508498/8508719'}
# {'Provider Name': 'ALABANG MEDICAL CLINIC-ALMANZA', 'Address': '2/F SUSANA ARCADE 476 REAL ST.,', 'Contact Number': '(02)8014535/8003840'}
# {'Provider Name': 'ALABANG MEDICAL CLINIC-MAIN', 'Address': '90 ML QUEZON WAWA ST. ALABANG', 'Contact Number': '0288420680'}
# {'Provider Name': 'ALABANG MEDICAL CLINIC-MUNTINLUPA', 'Address': '1 NATL RD., PUTATAN MUNTINLUPA CITY', 'Contact Number': '(02)8611135/8611779'}
# {'Provider Name': 'ALABANG MEDICAL CLINIC-TALON', 'Address': 'ALABANG ZAPOTE RD., COR MENDOZA ST., PELAYO VILL TALON, LAS PINAS CITY', 'Contact Number': '(02)8736464/8742506'}
# {'Provider Name': "ALBAY DOCTORS' HOSPITAL, INC.", 'Address': 'PEÑARANDA ST. LEGAZPI PORT DISTRICT, LEGAZPI CITY', 'Contact Number': '(052)4807838/4807848/4807858/4806747'}
# {'Provider Name': 'ALLAH VALLEY MEDICAL SPECIALISTS CENTER, INC.', 'Address': 'PUROK VILLEGAS, GEN SAN DRIVE,', 'Contact Number': '(083) 228 3550'}
# {'Provider Name': 'ALLCARE PAIN MANAGEMENT PHYSICAL THERAPY SERVICES', 'Address': '865 NATIONAL HIGHWAY GF EPICENTER BUILDING, BALAGTAS BATANGAS', 'Contact Number': '(043) 425 0394'}
# {'Provider Name': 'ALLEGIANT REGIONAL CARE HOSPITALS', 'Address': 'SITIO MALINAO BRGY. AGUS', 'Contact Number': '(032)4934248-51'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MALOLOS DOCTORS INC.', 'Address': 'CAPITOL VIEW PARK SUBD. BULIHAN', 'Contact Number': '044-8167698'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MED. CENTER-BAYPOINTE INC.', 'Address': 'BLK. 8 LOT 1A AND 1B DEWEY AVENUE, CBD AREA, SUBIC BAY FREEPORT ZONE', 'Contact Number': '(047) 250 6070'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER - MANDALUYONG', 'Address': '145 HAIG ST. BRGY DAANG BAKAL', 'Contact Number': ''}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER - PANGASINAN', 'Address': '23 DE VENECIA RD MALUED', 'Contact Number': '0752237264'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER BAYAWAN-INC.', 'Address': 'INTEGRATED BUSINESS CENTER, BRGY VILLAREAL', 'Contact Number': '035 - 523 - 6594'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER- CAGAYAN DE ORO', 'Address': 'PIMENTEL ST.  LAPASAN,', 'Contact Number': ''}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-BALIWAG', 'Address': 'LOT 2975 C-1 DOÑA REMEDIOS TRINIDAD HIGHWAY, PINAGBARILAN', 'Contact Number': '(044) 816-1001 loc 103 or (8) 584-4665 / 514-5330'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-BOHOL, INC', 'Address': '0368 CARLOS P. GARCIA EAST AVENUE', 'Contact Number': '038-412-8888'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-BUTUAN INC.', 'Address': 'SOUTH MONTILLA BLVD, VILLA KANANGA', 'Contact Number': '085-8154874'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-CEBU INC.', 'Address': '494 NATIONAL HIGHWAY N. BACALSO AVE. BASAK PARDO', 'Contact Number': '(032) 2655833'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-LEGAZPI', 'Address': 'DARAGA-LEGAZPI DIVERSION RD. BRGY. BOGTONG', 'Contact Number': '09176267692'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-PALAWAN, INC.', 'Address': 'SOUTH NATIONAL HIGHWAY, SAN PEDRO, PALAWAN', 'Contact Number': '048-7170019'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-TACLOBAN', 'Address': 'MARASBARAS, BARANGAY 78,, TACLOBAN CITY', 'Contact Number': '(053)888-4322'}
# {'Provider Name': 'ALLIED CARE EXPERTS (ACE) MEDICAL CENTER-TUGUEGARAO', 'Address': 'PALLUA RD. BRGY PALLUA NORTE', 'Contact Number': ''}
# {'Provider Name': 'ALLIED CARE EXPERTS MEDICAL CENTER-VALENZUELA', 'Address': '544 MC ARTHUR HIGHWAY, MALANDAY, VALENZUELA', 'Contact Number': '(02) 3660000/8366 0000 loc 618'}
# {'Provider Name': 'ALLIED CARE EXPERTS MEDICAL CENTER-ZAMBOANGA CITY', 'Address': 'BARANGAY 16 TIANO AKUT STREET', 'Contact Number': ''}
# {'Provider Name': 'ALLIED CARE MEDICAL EXPERTS (ACE) MEDICAL CENTER-PATEROS, INC.', 'Address': '884 P. HERRERA ST. AGUHO, PATEROS', 'Contact Number': '02-8706-9395 to 8706-9400'}
# {'Provider Name': 'ALPHAMED DIAGNOSTIC LABORATORY (MAIN)', 'Address': 'BARANGAY SAN ISIDRO, CITY OF SAN FERNANDO PAMPANGA', 'Contact Number': ''}
# {'Provider Name': 'ALPHAMED DIAGNOSTIC LABORATORY - APALIT', 'Address': 'BARANGAY SAN VICENTE, APALIT PAMPANGA', 'Contact Number': ''}

# %%
import pandas as pd

data_dict = ({
    "Provider Name": provider,
    "Address": address,
    "Contact Number": contact
})
df = pd.DataFrame(data)
df.head(100)
# Out:
#                                         Provider Name  \
# 0                               TAGUM EYE SURGICENTER
# 1                     CORE PHYSIOTHERAPY SERVICES OPC
# 2       DIPOLOG DOCTORS MEDICAL AND DIAGNOSTIC CLINIC
# 3                                   FIX AND HEALTH ME
# 4        OPTIMUM HEALTHCARE (SOLID SOUTH MEDI 6 INC.)
# ..                                                ...
# 95      ALLIED CARE EXPERTS MEDICAL CENTER-VALENZUELA
# 96  ALLIED CARE EXPERTS MEDICAL CENTER-ZAMBOANGA CITY
# 97  ALLIED CARE MEDICAL EXPERTS (ACE) MEDICAL CENT...
# 98              ALPHAMED DIAGNOSTIC LABORATORY (MAIN)
# 99            ALPHAMED DIAGNOSTIC LABORATORY - APALIT
#
#                                               Address  \
# 0     GCA BUILDING, NATIONAL HIGHWAY, VISAYAN VILLAGE
# 1   2ND FLOOR HOOGAH BUILDING J.P LAUREL HIGHWAY, ...
# 2                     PUROK MORNINGSTAR BRGY. OLINGAN
# 3   EASTBLOCK BLDG A DOOR 12A, CIRCUMFERENTIAL RD ...
# 4   BLOCK 3 LOT 3 E. RODRIGUEZ AVE. GREGORIA HEIGH...
# ..                                                ...
# 95        544 MC ARTHUR HIGHWAY, MALANDAY, VALENZUELA
# 96                      BARANGAY 16 TIANO AKUT STREET
# 97                  884 P. HERRERA ST. AGUHO, PATEROS
# 98  BARANGAY SAN ISIDRO, CITY OF SAN FERNANDO PAMP...
# 99              BARANGAY SAN VICENTE, APALIT PAMPANGA
#
#                     Contact Number
# 0                   (084) 655 6751
# 1
# 2
# 3
# 4                   (02) 8398 3067
# ..                             ...
# 95  (02) 3660000/8366 0000 loc 618
# 96
# 97       02-8706-9395 to 8706-9400
# 98
# 99
#
# [100 rows x 3 columns]

# %%
df.to_csv("hospital.csv")

# %% [markdown]
# # 7.2 Conclusion:

# %% [markdown]
# In conclusion, I had to modify 5 csv files to combine them into a single file and store them in a datafram of the FAANG data, and using ticker we can abreviate them to their specific stock or security listing. After that execercise 2 we were tasked to convert their data types into integers and sort them by their dates and ticker after their conversion, also output the seven rows with the highest value by the their volume. Lastly exercise 3 was us using webscraping again but this time to scrape a dataset containing 100 list of hospitals including their address and contact information. I had to first get the required data using inspect and snoop around the website to get the required data I need, then using selenium, soups and indexing I can limit or increase the amount of data outputted because if we did not index it it will not show 100 but only limit it to 10.
